# %%
yas = input("75 yaşından büyük ve sigara bağımlısımısınız (Evet/Hayır) ").title() == "Evet"
kronik = input("Kronik bir rahatsızlığınız var mı (Evet/Hayır) ").title() == "Evet"
b_sistem = input("Bağışıklık sisteminiz zayıf mı (Evet/Hayır) ").title() == "Evet"
risk = yas or kronik or b_sistem
if risk == 1:
  print("Riskli Guruptasınız")
else:
  print("Hayati Tehlikeniz yok / Riskli gurupta değilsiniz")
# Out:
# 75 yaşından büyük ve sigara bağımlısımısınız (Evet/Hayır) evet
# Kronik bir rahatsızlığınız var mı (Evet/Hayır) evet
# Bağışıklık sisteminiz zayıf mı (Evet/Hayır) evet
# Riskli Guruptasınız
