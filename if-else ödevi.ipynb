# %%
name = input("Şifreyi görmek için bir isim girin : ")
name = name.title()
if name == "Balkan":
    print('Hello Balkan! Parola : Clarusway ')
else:
    print(f"Hello {name}! See you leter.")
# Out:
# Şifreyi görmek için bir isim girin : balkan
# Hello Balkan! Parola : Clarusway
