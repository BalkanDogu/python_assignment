# %%
        ###   CÜMLE İÇİNDEKİ KARAKTER SAYISI   #####

sözlük = {}
sentence = input("Bir cümle girin :")
for i in sentence:
    sözlük[i] = sentence.count(i)
print(sözlük)
# Out:
# Bir cümle girin :Bana bir masal anlat baba içinde İstanbul olsun!
# {'B': 1, 'a': 9, 'n': 5, ' ': 7, 'b': 4, 'i': 3, 'r': 1, 'm': 1, 's': 3, 'l': 4, 't': 2, 'ç': 1, 'd': 1, 'e': 1, 'İ': 1, 'u': 2, 'o': 1, '!': 1}
